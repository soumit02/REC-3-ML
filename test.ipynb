# %%
import pandas as pd
print("Hello from Jupyter inside PyCharm!")
# Out:
# Hello from Jupyter inside PyCharm!

# %%
import sys, numpy, pandas, sklearn
print(sys.executable)
print(numpy.__version__)
print(pandas.__version__)
print(sklearn.__version__)
# Out:
# /home/soumit/PycharmProjects/REC-3-ML/.venv/bin/python3
# 2.3.5
# 2.3.3
# 1.8.0
